# %% [markdown]
# # PART3 特徴量を作ってみよう

# %% [markdown]
# ## おまじない

# %%
import pandas as pd
import numpy as np
#matplotlib inline
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression as LR

# %% [markdown]
# ## データの読み込み
# - train.csvとtest.csvとsample.csvの３つのファイルを読み込みましょう
# - それぞれを読み込んだものは変数はtrain, test, sampleに代入しましょう
# - sampleを読み込む時は、header=Noneというオプションを忘れないようにしましょう

# %%
train = pd.read_csv("bento/train.csv")
test = pd.read_csv("bento/test.csv")
sample = pd.read_csv("bento/sample.csv", header=None)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-26cd73e107ee> in <module>
# ----> 1 train = pd.read_csv("bento/train.csv")
#       2 test = pd.read_csv("bento/test.csv")
#       3 sample = pd.read_csv("bento/sample.csv", header=None)
#
# ~\Anaconda3\envs\bento_bank\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~\Anaconda3\envs\bento_bank\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# ~\Anaconda3\envs\bento_bank\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda3\envs\bento_bank\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# ~\Anaconda3\envs\bento_bank\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'bento/train.csv' does not exist: b'bento/train.csv'

# %% [markdown]
# ## yの折れ線グラフを描いてみましょう

# %%
train["y"].plot(figsize=(12, 4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1dc62df695e8> in <module>
# ----> 1 train["y"].plot(figsize=(12, 4))
#
# NameError: name 'train' is not defined

# %% [markdown]
# ## trainの先頭行を表示してみよう

# %%
train.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-3b77fa18a747> in <module>
# ----> 1 train.head()
#
# NameError: name 'train' is not defined

# %% [markdown]
# ## trainのdatetimeから年と月のデータを取り出し、trainの新たなカラムとして追加しましょう
# - apply関数とsplit関数を使います
# - 年の新しいカラム名はyearとし、月の新しいカラム名はmonthとしましょう

# %%
train["year"] = train["datetime"].apply(lambda x :x.split("-")[0])
train["month"] = train["datetime"].apply(lambda x :x.split("-")[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-1783d1d71bdb> in <module>
# ----> 1 train["year"] = train["datetime"].apply(lambda x :x.split("-")[0])
#       2 train["month"] = train["datetime"].apply(lambda x :x.split("-")[1])
#
# NameError: name 'train' is not defined

# %% [markdown]
# ## trainの中身を確認してみましょう

# %%
train.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>datetime</th>
#       <th>y</th>
#       <th>week</th>
#       <th>soldout</th>
#       <th>name</th>
#       <th>kcal</th>
#       <th>remarks</th>
#       <th>event</th>
#       <th>payday</th>
#       <th>weather</th>
#       <th>precipitation</th>
#       <th>temperature</th>
#       <th>year</th>
#       <th>month</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2013-11-18</td>
#       <td>90</td>
#       <td>月</td>
#       <td>0</td>
#       <td>厚切りイカフライ</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>快晴</td>
#       <td>--</td>
#       <td>19.8</td>
#       <td>2013</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2013-11-19</td>
#       <td>101</td>
#       <td>火</td>
#       <td>1</td>
#       <td>手作りヒレカツ</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>快晴</td>
#       <td>--</td>
#       <td>17.0</td>
#       <td>2013</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2013-11-20</td>
#       <td>118</td>
#       <td>水</td>
#       <td>0</td>
#       <td>白身魚唐揚げ野菜あん</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>快晴</td>
#       <td>--</td>
#       <td>15.5</td>
#       <td>2013</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2013-11-21</td>
#       <td>120</td>
#       <td>木</td>
#       <td>1</td>
#       <td>若鶏ピリ辛焼</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>快晴</td>
#       <td>--</td>
#       <td>15.2</td>
#       <td>2013</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2013-11-22</td>
#       <td>130</td>
#       <td>金</td>
#       <td>1</td>
#       <td>ビッグメンチカツ</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>快晴</td>
#       <td>--</td>
#       <td>16.1</td>
#       <td>2013</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## 同様にtestもdatetimeから年と月のデータを取り出し、testの新たなカラムとして追加しましょう

# %%
test["year"] = test["datetime"].apply(lambda x :x.split("-")[0])
test["month"] = test["datetime"].apply(lambda x :x.split("-")[1])
test.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>datetime</th>
#       <th>week</th>
#       <th>soldout</th>
#       <th>name</th>
#       <th>kcal</th>
#       <th>remarks</th>
#       <th>event</th>
#       <th>payday</th>
#       <th>weather</th>
#       <th>precipitation</th>
#       <th>temperature</th>
#       <th>year</th>
#       <th>month</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2014-10-1</td>
#       <td>水</td>
#       <td>1</td>
#       <td>メンチカツ</td>
#       <td>420.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>雨</td>
#       <td>0</td>
#       <td>20.2</td>
#       <td>2014</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2014-10-2</td>
#       <td>木</td>
#       <td>0</td>
#       <td>バーベキューチキン</td>
#       <td>415.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>曇</td>
#       <td>--</td>
#       <td>23.9</td>
#       <td>2014</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2014-10-3</td>
#       <td>金</td>
#       <td>0</td>
#       <td>豚肉のマスタード焼き</td>
#       <td>405.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>晴れ</td>
#       <td>--</td>
#       <td>28.7</td>
#       <td>2014</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2014-10-6</td>
#       <td>月</td>
#       <td>1</td>
#       <td>麻婆春雨</td>
#       <td>400.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>雨</td>
#       <td>0.5</td>
#       <td>21.5</td>
#       <td>2014</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2014-10-7</td>
#       <td>火</td>
#       <td>0</td>
#       <td>厚揚げ肉みそ炒め</td>
#       <td>430.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>晴れ</td>
#       <td>--</td>
#       <td>22.1</td>
#       <td>2014</td>
#       <td>10</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## trainのデータの型を確認してみましょう

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 14 columns):
# datetime         207 non-null object
# y                207 non-null int64
# week             207 non-null object
# soldout          207 non-null int64
# name             207 non-null object
# kcal             166 non-null float64
# remarks          21 non-null object
# event            14 non-null object
# payday           10 non-null float64
# weather          207 non-null object
# precipitation    207 non-null object
# temperature      207 non-null float64
# year             207 non-null object
# month            207 non-null object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 22.7+ KB

# %% [markdown]
# ## train,testのデータの型を整数（int）に変換しましょう
# - データの型を変換したい場合は、astype関数を使います
# - オプションにはデータの型を入れます。今回は整数に変換したい為、np.intと書きます
# - 変換したものは、もとのカラムに代入しなおしましょう

# %%
train["year"] = train["year"].astype(np.int)
train["month"] = train["month"].astype(np.int)
test["year"] = test["year"].astype(np.int)
test["month"] = test["month"].astype(np.int)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 14 columns):
# datetime         207 non-null object
# y                207 non-null int64
# week             207 non-null object
# soldout          207 non-null int64
# name             207 non-null object
# kcal             166 non-null float64
# remarks          21 non-null object
# event            14 non-null object
# payday           10 non-null float64
# weather          207 non-null object
# precipitation    207 non-null object
# temperature      207 non-null float64
# year             207 non-null int32
# month            207 non-null int32
# dtypes: float64(3), int32(2), int64(2), object(7)
# memory usage: 21.1+ KB

# %% [markdown]
# ## train,testからyearとmonthを取り出し、変数trainX,testXに代入しましょう

# %%
trainX = train[["year", "month"]]
testX = test[["year", "month"]]

# %% [markdown]
# ## trainXの中身を確認してみましょう

# %%
trainX.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>year</th>
#       <th>month</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2013</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2013</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2013</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2013</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2013</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## trainからyを取り出し、変数yに代入しましょう

# %%
y = train["y"]

# %% [markdown]
# ## 回帰モデルの箱を用意しましょう
# - 変数名はmodel1としましょう

# %%
model1 = LR()

# %% [markdown]
# ## 重回帰モデルを作りましょう

# %%
model1.fit(trainX, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ## 作ったモデルの傾きや切片を確かめてみましょう

# %%
model1.coef_
# Out:
# array([-104.0107109 ,   -7.41004428])

# %%
model1.intercept_
# Out:
# 209594.15656370917

# %% [markdown]
# ## testXを使って予測をし、予測結果を変数predに代入しましょう

# %%
pred = model1.predict(testX)

# %% [markdown]
# ## sample[1]に予測結果を代入しましょう

# %%
sample[1] = pred

# %% [markdown]
# ## sampleを"submit4.csv"というファイルで出力して、DeepAnalyticsに投稿しましょう

# %%
sample.to_csv("bento/submit4.csv", index=None, header=None)

# %% [markdown]
# ## 追加する特徴量検討の為に、trainXに対する予測値を変数predに代入しましょう
# - trainXに対して予測を行えば、実際の売り上げyがわかっているので、その差を比較することができます
# - そこでtrainXに対する予測値と、実際の売り上げyとを引き算することで、どの日が大きく予測を外していたかを確認します
# - 大きく外れていたものから共通する要素が見つけられれば、その要素を加えることで更に精度が良いモデルを作れる可能性があります
# - その準備として、まずmodel1とtrainXを使って、trainXに対する予測値を求めましょう

# %%
pred = model1.predict(trainX)

# %% [markdown]
# ## predをtrainの新たなカラムpredとして代入しましょう

# %%
train["pred"] = pred

# %% [markdown]
# ## trainのyとpredを引き算した結果をtrainの新たなカラムresとして代入しましょう
# - yとpredを引き算する為には、単純にtrain["y"] - train["pred"]と書きます

# %%
train["res"] = train["y"] - train["pred"]

# %% [markdown]
# ## trainのresでソートして中身を確認しましょう
# - 今回はhead関数を使わず、表示しましょう

# %%
train.sort_values(by="res")
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>datetime</th>
#       <th>y</th>
#       <th>week</th>
#       <th>soldout</th>
#       <th>name</th>
#       <th>kcal</th>
#       <th>remarks</th>
#       <th>event</th>
#       <th>payday</th>
#       <th>weather</th>
#       <th>precipitation</th>
#       <th>temperature</th>
#       <th>year</th>
#       <th>month</th>
#       <th>pred</th>
#       <th>res</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>27</th>
#       <td>2013-12-26</td>
#       <td>80</td>
#       <td>木</td>
#       <td>0</td>
#       <td>酢豚</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>曇</td>
#       <td>--</td>
#       <td>7.3</td>
#       <td>2013</td>
#       <td>12</td>
#       <td>131.674984</td>
#       <td>-51.674984</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>2013-11-18</td>
#       <td>90</td>
#       <td>月</td>
#       <td>0</td>
#       <td>厚切りイカフライ</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>快晴</td>
#       <td>--</td>
#       <td>19.8</td>
#       <td>2013</td>
#       <td>11</td>
#       <td>139.085028</td>
#       <td>-49.085028</td>
#     </tr>
#     <tr>
#       <th>81</th>
#       <td>2014-3-26</td>
#       <td>51</td>
#       <td>水</td>
#       <td>0</td>
#       <td>肉団子クリームシチュー</td>
#       <td>392.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>曇</td>
#       <td>--</td>
#       <td>18.7</td>
#       <td>2014</td>
#       <td>3</td>
#       <td>94.354672</td>
#       <td>-43.354672</td>
#     </tr>
#     <tr>
#       <th>82</th>
#       <td>2014-3-27</td>
#       <td>55</td>
#       <td>木</td>
#       <td>1</td>
#       <td>ロース甘味噌焼き</td>
#       <td>315.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>曇</td>
#       <td>1.5</td>
#       <td>12.4</td>
#       <td>2014</td>
#       <td>3</td>
#       <td>94.354672</td>
#       <td>-39.354672</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2013-11-19</td>
#       <td>101</td>
#       <td>火</td>
#       <td>1</td>
#       <td>手作りヒレカツ</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>快晴</td>
#       <td>--</td>
#       <td
td>
#       <td>NaN</td>
#       <td>1.0</td>
#       <td>曇</td>
#       <td>--</td>
#       <td>31.1</td>
#       <td>2014</td>
#       <td>8</td>
#       <td>57.304450</td>
#       <td>71.695550</td>
#     </tr>
#   </tbody>
# </table>
# <p>207 rows × 16 columns</p>
# </div>

# %% [markdown]
# ## 値が「お楽しみメニュー」であれば１、そうでなければ0とする自作関数を作りましょう
# - 自作の関数を作る為には、defを使います

# %%
def jisaku1(x):
    if x == "お楽しみメニュー":
        return 1
    else:
        return 0

# %% [markdown]
# ## jisaku1関数とapply関数を使って、trainとtestの新たなカラムfunを作りましょう

# %%
train["fun"] = train["remarks"].apply(lambda x :jisaku1(x))
test["fun"] = test["remarks"].apply(lambda x :jisaku1(x))

# %% [markdown]
# ## trainの中身を確認してみましょう

# %%
train.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>datetime</th>
#       <th>y</th>
#       <th>week</th>
#       <th>soldout</th>
#       <th>name</th>
#       <th>kcal</th>
#       <th>remarks</th>
#       <th>event</th>
#       <th>payday</th>
#       <th>weather</th>
#       <th>precipitation</th>
#       <th>temperature</th>
#       <th>year</th>
#       <th>month</th>
#       <th>pred</th>
#       <th>res</th>
#       <th>fun</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2013-11-18</td>
#       <td>90</td>
#       <td>月</td>
#       <td>0</td>
#       <td>厚切りイカフライ</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>快晴</td>
#       <td>--</td>
#       <td>19.8</td>
#       <td>2013</td>
#       <td>11</td>
#       <td>139.085028</td>
#       <td>-49.085028</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2013-11-19</td>
#       <td>101</td>
#       <td>火</td>
#       <td>1</td>
#       <td>手作りヒレカツ</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>快晴</td>
#       <td>--</td>
#       <td>17.0</td>
#       <td>2013</td>
#       <td>11</td>
#       <td>139.085028</td>
#       <td>-38.085028</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2013-11-20</td>
#       <td>118</td>
#       <td>水</td>
#       <td>0</td>
#       <td>白身魚唐揚げ野菜あん</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>快晴</td>
#       <td>--</td>
#       <td>15.5</td>
#       <td>2013</td>
#       <td>11</td>
#       <td>139.085028</td>
#       <td>-21.085028</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2013-11-21</td>
#       <td>120</td>
#       <td>木</td>
#       <td>1</td>
#       <td>若鶏ピリ辛焼</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>快晴</td>
#       <td>--</td>
#       <td>15.2</td>
#       <td>2013</td>
#       <td>11</td>
#       <td>139.085028</td>
#       <td>-19.085028</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2013-11-22</td>
#       <td>130</td>
#       <td>金</td>
#       <td>1</td>
#       <td>ビッグメンチカツ</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>快晴</td>
#       <td>--</td>
#       <td>16.1</td>
#       <td>2013</td>
#       <td>11</td>
#       <td>139.085028</td>
#       <td>-9.085028</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## train,testからyearとmonth、funとtemperatureの4カラムを取り出し、変数trainX,testXに代入しましょう

# %% [markdown]
# ## 回帰モデルの箱を用意しましょう
# - 変数名はmodel2としましょう

# %% [markdown]
# ## 重回帰モデルを作りましょう

# %% [markdown]
# ## 作ったモデルの傾きや切片を確かめてみましょう

# %% [markdown]
# ## testXを使って予測をし、予測結果を変数pred2に代入しましょう

# %% [markdown]
# ## sample[1]に予測結果を代入しましょう

# %% [markdown]
# ## sampleを"submit5.csv"というファイルで出力して、DeepAnalyticsに投稿しましょう
