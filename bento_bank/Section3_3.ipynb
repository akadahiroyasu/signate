# %% [markdown]
# # PART3 グラフを描いてみよう

# %% [markdown]
# ## おまじない

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
from matplotlib import pyplot as plt

# %% [markdown]
# ## データの読み込み
# - train.csvを読み込みましょう
# - 読み込んだものは変数trainに代入しましょう

# %%
train = pd.read_csv("bento/train.csv")

# %% [markdown]
# ## trainの先頭行を確かめてみましょう

# %%
train.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>datetime</th>
#       <th>y</th>
#       <th>week</th>
#       <th>soldout</th>
#       <th>name</th>
#       <th>kcal</th>
#       <th>remarks</th>
#       <th>event</th>
#       <th>payday</th>
#       <th>weather</th>
#       <th>precipitation</th>
#       <th>temperature</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2013-11-18</td>
#       <td>90</td>
#       <td>月</td>
#       <td>0</td>
#       <td>厚切りイカフライ</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>快晴</td>
#       <td>--</td>
#       <td>19.8</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2013-11-19</td>
#       <td>101</td>
#       <td>火</td>
#       <td>1</td>
#       <td>手作りヒレカツ</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>快晴</td>
#       <td>--</td>
#       <td>17.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2013-11-20</td>
#       <td>118</td>
#       <td>水</td>
#       <td>0</td>
#       <td>白身魚唐揚げ野菜あん</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>快晴</td>
#       <td>--</td>
#       <td>15.5</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2013-11-21</td>
#       <td>120</td>
#       <td>木</td>
#       <td>1</td>
#       <td>若鶏ピリ辛焼</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>快晴</td>
#       <td>--</td>
#       <td>15.2</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2013-11-22</td>
#       <td>130</td>
#       <td>金</td>
#       <td>1</td>
#       <td>ビッグメンチカツ</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>快晴</td>
#       <td>--</td>
#       <td>16.1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## trainのyの折れ線グラフを描いてみましょう
# - 折れ線グラフを描くにはplot関数を使います

# %%
train["y"].plot()
# Out:
# findfont: Font family ['IPAexGothic'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ## グラフの大きさをもっと大きくしてみましょう
# - カッコの中にオプションとしてfigsize=(12,4)と書きます

# %%
train["y"].plot(figsize=(12, 4))

# %% [markdown]
# ## グラフにタイトルをつけてみましょう
# - カッコの中にオプションとして、title="XXX"と書きます
# - カッコの中が複数となった場合はカンマ（,）を使うことで複数書くことができます

# %%
train["y"].plot(figsize=(12, 4), title="title")
# Out:
# findfont: Font family ['IPAexGothic'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ## グラフのx軸とy軸に名前を付けてみましょう
# - ちょっと複雑で一旦、plot関数の結果を別の変数に代入する必要があります
# - 今回は変数axに代入することにします
# - x軸はaxを使い、set_xlabel("name")と書くことで名前をつけることができます

# %%
ax = train["y"].plot(figsize=(12, 4), title="title")
ax.set_xlabel("time")
ax.set_ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ## trainのyのヒストグラムを描いてみましょう
# - グラフを描く前に簡単にヒストグラムとは何かを理解しましょう
# - plot.hist関数を使います

# %%
train["y"].plot.hist()

# %% [markdown]
# ## グリッド線を引いてみましょう
# - カッコの中にオプションとして、grid=Trueと書きます

# %%
train["y"].plot.hist(grid=True)

# %% [markdown]
# ## ヒストグラム上に平均値を表す赤線を描きましょう
# - ヒストグラムで一番数が多いところが平均値とは限らないケースもある為、ヒストグラムに平均値を表す線を描いてみましょう
# - まず縦線の描き方から始めます。縦線を描くときにはplt.axvline(x=NUMBER, color="red")と書きます
# - vlineのvはvertical（垂直）

# %%
plt.axvline(x=2, color="red")

# %%
plt.axvline(x=train["y"].mean(), color="red")
train["y"].plot.hist()

# %% [markdown]
# ## 上記のヒストグラムを大きさ(12,4)にし、タイトルを"ヒストグラム"として、pngファイルの図として保存しましょう
# - plt.savefig("FILE_NAME.拡張子")を一番最後に書きます
# - ファイル名は「sample_fig.png」としましょう

# %%
train["y"].plot.hist(figsize=(12, 4), title="title")
plt.axvline(x=train["y"].mean(), color="red")
plt.savefig("bento/sample_fig.png")

# %% [markdown]
# ## yとweekの関係を調べる為に、箱ひげ図を描いてみましょう
# - 箱ひげ図を描く前に簡単に箱ひげ図とは何かを理解しましょう
# - 箱ひげ図の描き方は、yとweekを選択した上で、boxplot(by="week")と書きます
# - by="week"はx軸にしたいカラムを選択します
# - ○は外れ値です

# %%
train[["y", "week"]].boxplot(by="week")
# Out:
# C:\Users\hiro\Anaconda3\envs\bento_bank\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 26376 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\hiro\Anaconda3\envs\bento_bank\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 26408 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\hiro\Anaconda3\envs\bento_bank\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 27700 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\hiro\Anaconda3\envs\bento_bank\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 28779 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\hiro\Anaconda3\envs\bento_bank\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 37329 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\hiro\Anaconda3\envs\bento_bank\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 26376 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\Users\hiro\Anaconda3\envs\bento_bank\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 26408 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\Users\hiro\Anaconda3\envs\bento_bank\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 27700 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\Users\hiro\Anaconda3\envs\bento_bank\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 28779 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\Users\hiro\Anaconda3\envs\bento_bank\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 37329 missing from current font.
#   font.load_char(ord(s), flags=flags)

# %% [markdown]
# # 実習

# %% [markdown]
# 1.trainのtemperatureの折れ線グラフを描いてみよう。タイトルとx軸、y軸にもそれぞれ名前をつけよう
# - x軸とy軸に名前を付ける為に、グラフは一旦変数axに代入しよう
# - タイトル名は「気温」、x軸は「time」、y軸は「temperature」としよう

# %%
ax = train["temperature"].plot(title="気温")
ax.set_xlabel("time")
ax.set_ylabel("temperature")
# Out:
# Text(0, 0.5, 'temperature')
# C:\Users\hiro\Anaconda3\envs\bento_bank\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 27671 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\hiro\Anaconda3\envs\bento_bank\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 28201 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\hiro\Anaconda3\envs\bento_bank\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 27671 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\hiro\Anaconda3\envs\bento_bank\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 28201 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# 2.trainのkcalのヒストグラムを描いてみよう。trainのkcalの平均を表す赤線も入れよう

# %%
train["kcal"].plot.hist()
plt.axvline(x=train["kcal"].mean(), color="red")

# %% [markdown]
# 3.trainのyとweatherとの関係を調べる為に、箱ひげ図を描いてみよう
# - x軸はweatherにしましょう

# %%
train[["y", "weather"]].boxplot(by="weather")
# Out:
# C:\Users\hiro\Anaconda3\envs\bento_bank\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 24555 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\hiro\Anaconda3\envs\bento_bank\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 26228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\hiro\Anaconda3\envs\bento_bank\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 12428 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\hiro\Anaconda3\envs\bento_bank\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 26311 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\hiro\Anaconda3\envs\bento_bank\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 34180 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\hiro\Anaconda3\envs\bento_bank\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 38632 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\hiro\Anaconda3\envs\bento_bank\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 38634 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\hiro\Anaconda3\envs\bento_bank\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 38647 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\hiro\Anaconda3\envs\bento_bank\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 38651 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\hiro\Anaconda3\envs\bento_bank\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 24555 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\hiro\Anaconda3\envs\bento_bank\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 26228 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\hiro\Anaconda3\envs\bento_bank\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 12428 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\hiro\Anaconda3\envs\bento_bank\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 26311 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\Users\hiro\Anaconda3\envs\bento_bank\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 34180 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\hiro\Anaconda3\envs\bento_bank\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 26311 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\hiro\Anaconda3\envs\bento_bank\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 38632 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\Users\hiro\Anaconda3\envs\bento_bank\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 38634 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\Users\hiro\Anaconda3\envs\bento_bank\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 38647 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\hiro\Anaconda3\envs\bento_bank\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 38651 missing from current font.
#   font.set_text(s, 0, flags=flags)
